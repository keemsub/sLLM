# %% [markdown]
# 베스트 셀러 저자의 목차 만들기

# %%
import requests
from bs4 import BeautifulSoup

url = "https://search.kyobobook.co.kr/search?keyword=chatgpt&gbCode=TOT&target=total"

response = requests.get(url)
# 사용자 에이전트(User-Agent) 설정
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.0.0 Safari/537.36"

# HTTP GET 요청 보내기 및 사용자 에이전트 설정
headers = {"User-Agent": user_agent}
response = requests.get(url, headers=headers)
if response.status_code == 200:  # 정상 연결시
    soup = BeautifulSoup(response.text, "html.parser")
    body = soup.find_all("li", attrs={"class": "prod_item"})
else:
    print(response.status_code)

# %%
body
# Out:
# [<li class="prod_item">
#  <!-- 체크박스 영역 -->
#  <!-- 체크박스 영역 -->
#  <span class="form_chk no_label">
#  <!--교보일때-->
#  <input class="result_checkbox spec_checkbox" data-bid="9788956749754" data-cdtn-code="001" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="챗GPT 프롬프트 120% 질문 기술" data-pid="S000213093628" data-prhb-age="0" id="chkSearch_S000213093628" name="001_001_S000213093628_chkSearchNm" type="checkbox"/>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <label for="chkSearch_S000213093628"><span class="hidden">상품선택</span></label>
#  </span>
#  <!-- // 체크박스 영역 -->
#  <!-- 상품 영역 -->
#  <div class="prod_area horizontal">
#  <div class="prod_thumb_box size_lg">
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000213093628" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000213093628&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9788956749754" data-kbbfn-pid="S000213093628" data-kbbfn-size="200x0" data-kbbfn-title="챗GPT 프롬프트 120% 질문 기술" data-kbbfn-type="KOR">
#  </img></span>
#  </a>
#  <div class="prod_viewer_control">
#  <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000213093628&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
#  </div>
#  </div>
#  <div class="prod_info_box">
#  <!-- 라벨 -->
#  <!-- 라벨 페이지 -->
#  <div class="prod_badge">
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
#  <span class="badge_md badge_line_gray"><span class="text">이벤트</span></span>
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  </div>
#  <!-- // 라벨 -->
#  <!-- 상품명 -->
#  <div class="auto_overflow_wrap prod_name_group">
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213093628" onclick="searchResultItemClickEvent('상품 제목', &quot;S000213093628&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000213093628">챗GPT 프롬프트 120% 질문 기술</span>
#  </a>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000213093628");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  <!-- LayerPopup area -->
#  <!-- 타이틀 전체보기 -->
#  <div class="dialog_wrap no_title" id="popAllProdTitle">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <div class="prod_detail_title_wrap">
#  <!-- prod_title_area -->
#  <div class="prod_title_area">
#  <!-- 상품 타이틀 -->
#  <div class="prod_title_box">
#  <!-- DESC : 상품 타이틀 구분 값 케이스
#                          - 일반 구분 값 : .prod_label
#                          - 관칭관제 : .prod_alias
#                          - 상품명 : .prod_title
#                      -->
#  <span class="prod_label" id="gubun1"></span>
#  <span class="gap gubun2">·</span>
#  <span class="prod_label" id="gubun2"></span>
#  <span class="gap gubun3">·</span>
#  <span class="prod_label" id="gubun3"></span>
#  <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  <h1>
#  <span class="prod_alias" id="kwch"></span>
#  <span class="prod_title" id="cmdtName"></span>
#  </h1>
#  <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  </div>
#  <!-- //상품 타이틀 -->
#  </div>
#  <!-- //prod_title_area -->
#  <!-- prod_desc_area -->
#  <div class="prod_desc_area">
#  <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc" id="subtitle_1"></span>
#  <span class="gap subtitle_2"> | </span>
#  <span class="prod_desc" id="subtitle_2"></span>
#  <span class="gap subtitle_3"> | </span>
#  <span class="prod_desc" id="subtitle_3"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc normal" id="splmCntt"></span>
#  <span class="gap bkbnShpName"> | </span>
#  <span class="prod_desc normal" id="bkbnShpName"></span>
#  <span class="gap setCnfgCmdtQntt"> | </span>
#  <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  </div>
#  <!-- //prod_desc_area -->
#  </div>
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- //타이틀 전체보기 -->
#  <!-- // LayerPopup area -->
#  </div>
#  </div>
#  <!-- // 상품명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_info">
#  <span class="prod_desc">업무 속도 10배 향상!</span>
#  </div>
#  <!-- // 상품 부제명 -->
#  <!-- 저자, 출판사 정보 -->
#  <div class="prod_author_info">
#  <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
#  <div class="auto_overflow_wrap prod_author_group">
#  <!--인물 페이지-->
#  <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;3002695001&quot;,&quot;ChatGPT \uBE44\uC988\uB2C8\uC2A4 \uC5F0\uAD6C\uD68C&quot;);">ChatGPT 비즈니스 연구회</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">저자(글)</span>
#  <span class="gap"> | </span>
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1102553802&quot;,&quot;\uAE40\uBAA8\uC138&quot;);">김모세</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">번역</span>
#  <span class="count">외</span>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@3002695001@ChatGPT \uBE44\uC988\uB2C8\uC2A4 \uC5F0\uAD6C\uD68C|003@1102553802@\uAE40\uBAA8\uC138");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  </div>
#  <!--인물 페이지-->
#  <!-- LayerPopup area -->
#  <!-- 저자 모두보기 팝업 -->
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_header -->
#  <div class="dialog_header">
#  <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
#  </div>
#  <!-- //dialog_header -->
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <!-- form_wrap -->
#  <div class="form_wrap type_md" id="authorBox">
#  </div>
#  <!-- //form_wrap -->
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <!-- //저자 모두보기 팝업 -->
#  <!-- // LayerPopup area -->
#  </div>
#  <div class="prod_publish">
#  <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB05806&quot;,&quot;\uC815\uBCF4\uBB38\uD654\uC0AC&quot;);">정보문화사</a>
#  <span class="gap">·</span>
#  <span class="date">2024년 04월 25일</span>
#  </div>
#  </div>
#  <!-- // 저자, 출판사 정보 -->
#  <!--가격정보 페이지-->
#  <!-- 가격정보 페이지 -->
#  <!--판매중일떄-->
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">13,500</span>
#  <span class="unit">원 </span>
#  </span>
#  <span class="price_normal">
#  <span class="text">정가</span>
#  <s class="val">15,000원</s>
#  </span>
#  <span class="gap">|</span>
#  <span class="point">
#                              750p
#                              <span class="rate">(5%)</span>
#  </span>
#  </div>
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  <!--판매중이 아닐떄-->
#  <!--중고 장터일때-->
#  <!--//가격정보 페이지-->
#  <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <div class="prod_bottom">
#  <!--좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9788956749754" data-pid="S000213093628" id="searchWishItemInfo_S000213093628" name="001_001_S000213093628_searchWishItemNm" type="hidden"/>
#  <button class="btn_wish_icon bottom" data-cmdtcode="9788956749754" id="S000213093628_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000213093628");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000213093628_CMDTCODE_VAL_BOTTOM">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!--클로버리뷰-->
#  <!-- 클로버 리뷰 페이지 -->
#  <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage("KOR", "S000213093628");'>
#  <span class="review_klover_box">
#  <span class="review_klover_text font_size_xxs">9.82</span>
#  <!--임시 조건-->
#  <span class="review_desc">(14)</span>
#  <!--//임시조건-->
#  </span>
#  <!--임시 조건-->
#  <span class="gap">/</span>
#  <span class="review_quotes_text font_size_xxs">도움돼요</span>
#  <!--//임시조건-->
#  </a>
#  <!--//클로버리뷰-->
#  </div>
#  <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <!-- 태그 -->
#  <div class="tag_wrap size_sm">
#  </div>
#  <!-- // 태그 -->
#  <!-- 이벤트 정보 -->
#  <!-- 이벤트 정보 -->
#  <!--
#      (이벤트아이디@이벤트내용@이벤트구분|이벤트아이디@이벤트내용@이벤트구분)
#      이벤트 구분
#      001: 이벤트
#      002: 사은품
#      003: 경품
#      -->
#  <div class="prod_gift_info"><a class="prod_gift_text" href="javascript:void(0);" onclick="goEventDetailPage(221821)">2024 서울국제도서전 초대 이벤트</a><div class="tooltip_wrap type_sm">
#  <div class="tooltip_inner">
#  <div class="tooltip_header">
#  <div class="tooltip_head_title">이벤트 안내</div>
#  </div>
#  <div class="tooltip_contents"><div class="tooltip_sub_title">이벤트</div><ul class="bul_list"><li class="bul_item_dot font_size_xxs"><a href="javascript:void(0);" onclick="goEventDetailPage(221821)">2024 서울국제도서전 초대 이벤트</a></li>
#  </ul></div>
#  <button class="btn_tooltip_close" type="button"><span class="hidden">툴팁닫기</span></button>
#  </div>
#  </div></div>
#  <!-- // 이벤트 정보 -->
#  <!-- // 이벤트 정보 -->
#  </div>
#  </div>
#  <!-- // 상품 영역 -->
#  <!-- only list type -->
#  <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
#  <!-- 배송정보 영역 -->
#  <!--바로드림 전용상품이 아닐경우-->
#  <div class="prod_order_state">
#  <div class="order_state_desc">
#  <!--<span>지금 주문하면</span> -->
#  <!--<br> -->
#  <span class="fw_bold">6/18(화)</span>
#  <br/>
#  <span>도착</span>
#  </div>
#  </div>
#  <!-- // 배송정보 영역 -->
#  <!--</th:block>-->
#  <!-- 리스트형 타입 버튼영역 -->
#  <div class="prod_btn_wrap">
#  <!--결제기능, 좋아요 버튼 정책 레이아웃-->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9788956749754" data-pid="S000213093628" id="searchWishItemInfo_S000213093628" name="001_001_S000213093628_searchWishItemNm" type="hidden"/>
#  <button class="btn_wish_icon" data-cmdtcode="9788956749754" id="S000213093628_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000213093628");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000213093628_CMDTCODE_VAL">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <!--캐스팅일때-->
#  <!--결제기능 버튼 정책 레이아웃-->
#  <div class="btn_wrap full">
#  <!--교보일때-->
#  <!--판매중/예약중 일떄-->
#  <!--or-->
#  <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
#  <a class="btn_sm btn_light_gray" href="javascript:;" onclick='searchResultCartClickEvent(false, "S000213093628");'><span class="text">장바구니</span></a>
#  <a class="btn_sm btn_line_primary" href="javascript:;" onclick='searchResultDirectPickUpClickEvent("S000213093628");'><span class="text">바로드림</span></a>
#  <a class="btn_sm btn_primary" href="javascript:;" onclick='searchResultDirectOrderClickEvent("S000213093628");'><span class="text">바로구매</span></a>
#  <!--품절 상품일때-->
#  <!--출시예정 상품일때-->
#  <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '004'">
#                  <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000213093628, SGK, KOR);"><span class="ico_alarm"></span><span class="text">출시알림</span></button>
#              </th:block>-->
#  <!--절판,품절,일시품절 일때-->
#  <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                  <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                      <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000213093628, , KOR);"><span class="ico_alarm"></span>
#                          <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                          <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                      </button>
#                  </th:block>
#              </th:block>-->
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
#  <!-- 앨범 일때-->
#  <!--중고 장터일때-->
#  </div>
#  <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
#  <ul class="prod_related_list">
#  <li class="btn_item">
#  <a class="btn_xxs btn_pill btn_line_gray" href="https://product.kyobobook.co.kr/detail/S000210530868" onclick="searchResultItemClickEvent('원서/번역서', &quot;S000213093628&quot;);">
#  <span class="text">원서/번역서</span><span class="ico_arw"></span>
#  </a>
#  </li>
#  <li class="btn_item">
#  <a class="btn_xxs btn_pill btn_line_gray" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007719746" onclick="searchResultItemClickEvent('eBook', &quot;S000213093628&quot;);">
#  <span class="text">eBook</span><span class="ico_arw"></span>
#  </a>
#  </li>
#
#  q
#
#
#
#
#                  </ul>
#  </div>
#  </li>,
#  <li class="prod_item">
#  <!-- 체크박스 영역 -->
#  <!-- 체크박스 영역 -->
#  <span class="form_chk no_label">
#  <!--교보일때-->
#  <input class="result_checkbox spec_checkbox" data-bid="9791169211932" data-cdtn-code="001" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="쉽고 빠르게 익히는 실전 LLM" data-pid="S000212147276" data-prhb-age="0" id="chkSearch_S000212147276" name="001_001_S000212147276_chkSearchNm" type="checkbox"/>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <label for="chkSearch_S000212147276"><span class="hidden">상품선택</span></label>
#  </span>
#  <!-- // 체크박스 영역 -->
#  <!-- 상품 영역 -->
#  <div class="prod_area horizontal">
#  <div class="prod_thumb_box size_lg">
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000212147276" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000212147276&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791169211932" data-kbbfn-pid="S000212147276" data-kbbfn-size="200x0" data-kbbfn-title="쉽고 빠르게 익히는 실전 LLM" data-kbbfn-type="KOR">
#  </img></span>
#  </a>
#  <div class="prod_viewer_control">
#  <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000212147276&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
#  </div>
#  </div>
#  <div class="prod_info_box">
#  <!-- 라벨 -->
#  <!-- 라벨 페이지 -->
#  <div class="prod_badge">
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  </div>
#  <!-- // 라벨 -->
#  <!-- 상품명 -->
#  <div class="auto_overflow_wrap prod_name_group">
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212147276" onclick="searchResultItemClickEvent('상품 제목', &quot;S000212147276&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000212147276">쉽고 빠르게 익히는 실전 LLM</span>
#  </a>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000212147276");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  <!-- LayerPopup area -->
#  <!-- 타이틀 전체보기 -->
#  <div class="dialog_wrap no_title" id="popAllProdTitle">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <div class="prod_detail_title_wrap">
#  <!-- prod_title_area -->
#  <div class="prod_title_area">
#  <!-- 상품 타이틀 -->
#  <div class="prod_title_box">
#  <!-- DESC : 상품 타이틀 구분 값 케이스
#                          - 일반 구분 값 : .prod_label
#                          - 관칭관제 : .prod_alias
#                          - 상품명 : .prod_title
#                      -->
#  <span class="prod_label" id="gubun1"></span>
#  <span class="gap gubun2">·</span>
#  <span class="prod_label" id="gubun2"></span>
#  <span class="gap gubun3">·</span>
#  <span class="prod_label" id="gubun3"></span>
#  <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  <h1>
#  <span class="prod_alias" id="kwch"></span>
#  <span class="prod_title" id="cmdtName"></span>
#  </h1>
#  <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  </div>
#  <!-- //상품 타이틀 -->
#  </div>
#  <!-- //prod_title_area -->
#  <!-- prod_desc_area -->
#  <div class="prod_desc_area">
#  <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc" id="subtitle_1"></span>
#  <span class="gap subtitle_2"> | </span>
#  <span class="prod_desc" id="subtitle_2"></span>
#  <span class="gap subtitle_3"> | </span>
#  <span class="prod_desc" id="subtitle_3"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc normal" id="splmCntt"></span>
#  <span class="gap bkbnShpName"> | </span>
#  <span class="prod_desc normal" id="bkbnShpName"></span>
#  <span class="gap setCnfgCmdtQntt"> | </span>
#  <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  </div>
#  <!-- //prod_desc_area -->
#  </div>
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- //타이틀 전체보기 -->
#  <!-- // LayerPopup area -->
#  </div>
#  </div>
#  <!-- // 상품명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_info">
#  <span class="prod_desc">ChatGPT 활용부터 LLM 파인튜닝, 임베딩, 고급 프롬프트 엔지니어링까지 LLM FAQ, AI/ML 용어 해설집 수록</span>
#  </div>
#  <!-- // 상품 부제명 -->
#  <!-- 저자, 출판사 정보 -->
#  <div class="prod_author_info">
#  <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
#  <div class="auto_overflow_wrap prod_author_group">
#  <!--인물 페이지-->
#  <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;2018754501&quot;,&quot;\uC2DC\uB09C \uC624\uC988\uB370\uBBF8\uB974&quot;);">시난 오즈데미르</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">저자(글)</span>
#  <span class="gap"> | </span>
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1118952901&quot;,&quot;\uC2E0\uBCD1\uD6C8&quot;);">신병훈</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">번역</span>
#  <span class="count">외</span>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@2018754501@\uC2DC\uB09C \uC624\uC988\uB370\uBBF8\uB974|003@1118952901@\uC2E0\uBCD1\uD6C8");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  </div>
#  <!--인물 페이지-->
#  <!-- LayerPopup area -->
#  <!-- 저자 모두보기 팝업 -->
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_header -->
#  <div class="dialog_header">
#  <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
#  </div>
#  <!-- //dialog_header -->
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <!-- form_wrap -->
#  <div class="form_wrap type_md" id="authorBox">
#  </div>
#  <!-- //form_wrap -->
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <!-- //저자 모두보기 팝업 -->
#  <!-- // LayerPopup area -->
#  </div>
#  <div class="prod_publish">
#  <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB60125&quot;,&quot;\uD55C\uBE5B\uBBF8\uB514\uC5B4&quot;);">한빛미디어</a>
#  <span class="gap">·</span>
#  <span class="date">2024년 02월 01일</span>
#  </div>
#  </div>
#  <!-- // 저자, 출판사 정보 -->
#  <!--가격정보 페이지-->
#  <!-- 가격정보 페이지 -->
#  <!--판매중일떄-->
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">25,200</span>
#  <span class="unit">원 </span>
#  </span>
#  <span class="price_normal">
#  <span class="text">정가</span>
#  <s class="val">28,000원</s>
#  </span>
#  <span class="gap">|</span>
#  <span class="point">
#                              1,400p
#                              <span class="rate">(5%)</span>
#  </span>
#  </div>
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  <!--판매중이 아닐떄-->
#  <!--중고 장터일때-->
#  <!--//가격정보 페이지-->
#  <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <div class="prod_bottom">
#  <!--좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791169211932" data-pid="S000212147276" id="searchWishItemInfo_S000212147276" name="001_001_S000212147276_searchWishItemNm" type="hidden"/>
#  <button class="btn_wish_icon bottom" data-cmdtcode="9791169211932" id="S000212147276_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000212147276");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000212147276_CMDTCODE_VAL_BOTTOM">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!--클로버리뷰-->
#  <!-- 클로버 리뷰 페이지 -->
#  <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage("KOR", "S000212147276");'>
#  <span class="review_klover_box">
#  <span class="review_klover_text font_size_xxs">9.69</span>
#  <!--임시 조건-->
#  <span class="review_desc">(15)</span>
#  <!--//임시조건-->
#  </span>
#  <!--임시 조건-->
#  <span class="gap">/</span>
#  <span class="review_quotes_text font_size_xxs">도움돼요</span>
#  <!--//임시조건-->
#  </a>
#  <!--//클로버리뷰-->
#  </div>
#  <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <!-- 태그 -->
#  <div class="tag_wrap size_sm">
#  </div>
#  <!-- // 태그 -->
#  <!-- 이벤트 정보 -->
#  <!-- // 이벤트 정보 -->
#  </div>
#  </div>
#  <!-- // 상품 영역 -->
#  <!-- only list type -->
#  <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
#  <!-- 배송정보 영역 -->
#  <!--바로드림 전용상품이 아닐경우-->
#  <div class="prod_order_state">
#  <div class="order_state_desc">
#  <!--<span>지금 주문하면</span> -->
#  <!--<br> -->
#  <span class="fw_bold">6/18(화)</span>
#  <br/>
#  <span>도착</span>
#  </div>
#  </div>
#  <!-- // 배송정보 영역 -->
#  <!--</th:block>-->
#  <!-- 리스트형 타입 버튼영역 -->
#  <div class="prod_btn_wrap">
#  <!--결제기능, 좋아요 버튼 정책 레이아웃-->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791169211932" data-pid="S000212147276" id="searchWishItemInfo_S000212147276" name="001_001_S000212147276_searchWishItemNm" type="hidden"/>
#  <button class="btn_wish_icon" data-cmdtcode="9791169211932" id="S000212147276_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000212147276");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000212147276_CMDTCODE_VAL">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <!--캐스팅일때-->
#  <!--결제기능 버튼 정책 레이아웃-->
#  <div class="btn_wrap full">
#  <!--교보일때-->
#  <!--판매중/예약중 일떄-->
#  <!--or-->
#  <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
#  <a class="btn_sm btn_light_gray" href="javascript:;" onclick='searchResultCartClickEvent(false, "S000212147276");'><span class="text">장바구니</span></a>
#  <a class="btn_sm btn_line_primary" href="javascript:;" onclick='searchResultDirectPickUpClickEvent("S000212147276");'><span class="text">바로드림</span></a>
#  <a class="btn_sm btn_primary" href="javascript:;" onclick='searchResultDirectOrderClickEvent("S000212147276");'><span class="text">바로구매</span></a>
#  <!--품절 상품일때-->
#  <!--출시예정 상품일때-->
#  <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '004'">
#                  <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000212147276, SGK, KOR);"><span class="ico_alarm"></span><span class="text">출시알림</span></button>
#              </th:block>-->
#  <!--절판,품절,일시품절 일때-->
#  <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                  <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                      <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000212147276, , KOR);"><span class="ico_alarm"></span>
#                          <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                          <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                      </button>
#                  </th:block>
#              </th:block>-->
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
#  <!-- 앨범 일때-->
#  <!--중고 장터일때-->
#  </div>
#  <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
#  <ul class="prod_related_list">
#  <li class="btn_item">
#  <a class="btn_xxs btn_pill btn_line_gray" href="https://product.kyobobook.co.kr/detail/S000208444406" onclick="searchResultItemClickEvent('원서/번역서', &quot;S000212147276&quot;);">
#  <span class="text">원서/번역서</span><span class="ico_arw"></span>
#  </a>
#  </li>
#  <li class="btn_item">
#  <a class="btn_xxs btn_pill btn_line_gray" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000006261430" onclick="searchResultItemClickEvent('eBook', &quot;S000212147276&quot;);">
#  <span class="text">eBook</span><span class="ico_arw"></span>
#  </a>
#  </li>
#
#  q
#
#
#
#
#                  </ul>
#  </div>
#  </li>,
#  <li class="prod_item">
#  <!-- 체크박스 영역 -->
#  <!-- 체크박스 영역 -->
#  <span class="form_chk no_label">
#  <!--교보일때-->
#  <input class="result_checkbox spec_checkbox" data-bid="9788956749761" data-cdtn-code="001" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="예제가 가득한 챗GPT 프롬프트 길라잡이" data-pid="S000213299307" data-prhb-age="0" id="chkSearch_S000213299307" name="001_001_S000213299307_chkSearchNm" type="checkbox"/>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <label for="chkSearch_S000213299307"><span class="hidden">상품선택</span></label>
#  </span>
#  <!-- // 체크박스 영역 -->
#  <!-- 상품 영역 -->
#  <div class="prod_area horizontal">
#  <div class="prod_thumb_box size_lg">
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000213299307" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000213299307&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9788956749761" data-kbbfn-pid="S000213299307" data-kbbfn-size="200x0" data-kbbfn-title="예제가 가득한 챗GPT 프롬프트 길라잡이" data-kbbfn-type="KOR">
#  </img></span>
#  </a>
#  <div class="prod_viewer_control">
#  <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000213299307&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
#  </div>
#  </div>
#  <div class="prod_info_box">
#  <!-- 라벨 -->
#  <!-- 라벨 페이지 -->
#  <div class="prod_badge">
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  </div>
#  <!-- // 라벨 -->
#  <!-- 상품명 -->
#  <div class="auto_overflow_wrap prod_name_group">
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213299307" onclick="searchResultItemClickEvent('상품 제목', &quot;S000213299307&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000213299307">예제가 가득한 챗GPT 프롬프트 길라잡이</span>
#  </a>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000213299307");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  <!-- LayerPopup area -->
#  <!-- 타이틀 전체보기 -->
#  <div class="dialog_wrap no_title" id="popAllProdTitle">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <div class="prod_detail_title_wrap">
#  <!-- prod_title_area -->
#  <div class="prod_title_area">
#  <!-- 상품 타이틀 -->
#  <div class="prod_title_box">
#  <!-- DESC : 상품 타이틀 구분 값 케이스
#                          - 일반 구분 값 : .prod_label
#                          - 관칭관제 : .prod_alias
#                          - 상품명 : .prod_title
#                      -->
#  <span class="prod_label" id="gubun1"></span>
#  <span class="gap gubun2">·</span>
#  <span class="prod_label" id="gubun2"></span>
#  <span class="gap gubun3">·</span>
#  <span class="prod_label" id="gubun3"></span>
#  <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  <h1>
#  <span class="prod_alias" id="kwch"></span>
#  <span class="prod_title" id="cmdtName"></span>
#  </h1>
#  <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  </div>
#  <!-- //상품 타이틀 -->
#  </div>
#  <!-- //prod_title_area -->
#  <!-- prod_desc_area -->
#  <div class="prod_desc_area">
#  <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc" id="subtitle_1"></span>
#  <span class="gap subtitle_2"> | </span>
#  <span class="prod_desc" id="subtitle_2"></span>
#  <span class="gap subtitle_3"> | </span>
#  <span class="prod_desc" id="subtitle_3"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc normal" id="splmCntt"></span>
#  <span class="gap bkbnShpName"> | </span>
#  <span class="prod_desc normal" id="bkbnShpName"></span>
#  <span class="gap setCnfgCmdtQntt"> | </span>
#  <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  </div>
#  <!-- //prod_desc_area -->
#  </div>
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- //타이틀 전체보기 -->
#  <!-- // LayerPopup area -->
#  </div>
#  </div>
#  <!-- // 상품명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_info">
#  <span class="prod_desc">한 권으로 끝내는 ChatGPT 입문!</span>
#  </div>
#  <!-- // 상품 부제명 -->
#  <!-- 저자, 출판사 정보 -->
#  <div class="prod_author_info">
#  <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
#  <div class="auto_overflow_wrap prod_author_group">
#  <!--인물 페이지-->
#  <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1000255323&quot;,&quot;\uC774\uC2B9\uC6B0&quot;);">이승우</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">저자(글)</span>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@1000255323@\uC774\uC2B9\uC6B0");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  </div>
#  <!--인물 페이지-->
#  <!-- LayerPopup area -->
#  <!-- 저자 모두보기 팝업 -->
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_header -->
#  <div class="dialog_header">
#  <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
#  </div>
#  <!-- //dialog_header -->
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <!-- form_wrap -->
#  <div class="form_wrap type_md" id="authorBox">
#  </div>
#  <!-- //form_wrap -->
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <!-- //저자 모두보기 팝업 -->
#  <!-- // LayerPopup area -->
#  </div>
#  <div class="prod_publish">
#  <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB05806&quot;,&quot;\uC815\uBCF4\uBB38\uD654\uC0AC&quot;);">정보문화사</a>
#  <span class="gap">·</span>
#  <span class="date">2024년 05월 20일</span>
#  </div>
#  </div>
#  <!-- // 저자, 출판사 정보 -->
#  <!--가격정보 페이지-->
#  <!-- 가격정보 페이지 -->
#  <!--판매중일떄-->
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">25,200</span>
#  <span class="unit">원 </span>
#  </span>
#  <span class="price_normal">
#  <span class="text">정가</span>
#  <s class="val">28,000원</s>
#  </span>
#  <span class="gap">|</span>
#  <span class="point">
#                              1,400p
#                              <span class="rate">(5%)</span>
#  </span>
#  </div>
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  <!--판매중이 아닐떄-->
#  <!--중고 장터일때-->
#  <!--//가격정보 페이지-->
#  <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <div class="prod_bottom">
#  <!--좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9788956749761" data-pid="S000213299307" id="searchWishItemInfo_S000213299307" name="001_001_S000213299307_searchWishItemNm" type="hidden"/>
#  <button class="btn_wish_icon bottom" data-cmdtcode="9788956749761" id="S000213299307_CMDTCODE_ICON_BOTTOM" onclick='searchResultWishClickEvent(this, false, "S000213299307");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000213299307_CMDTCODE_VAL_BOTTOM">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <!--//좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!--클로버리뷰-->
#  <!-- 클로버 리뷰 페이지 -->
#  <a class="review_summary_wrap type_sm" href="javascript:void(0);" onclick='goKloverReviewPage("KOR", "S000213299307");'>
#  <span class="review_klover_box">
#  <span class="review_klover_text font_size_xxs">10.0</span>
#  <!--임시 조건-->
#  <span class="review_desc">(7)</span>
#  <!--//임시조건-->
#  </span>
#  <!--임시 조건-->
#  <span class="gap">/</span>
#  <span class="review_quotes_text font_size_xxs">도움돼요</span>
#  <!--//임시조건-->
#  </a>
#  <!--//클로버리뷰-->
#  </div>
#  <!-- // 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <!-- 태그 -->
#  <div class="tag_wrap size_sm">
#  </div>
#  <!-- // 태그 -->
#  <!-- 이벤트 정보 -->
#  <!-- // 이벤트 정보 -->
#  </div>
#  </div>
#  <!-- // 상품 영역 -->
#  <!-- only list type -->
#  <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'KOR' or ${item.SALE_CMDT_DVSN_CODE} eq 'ENG' or ${item.SALE_CMDT_DVSN_CODE} eq 'JAP' or ${item.SALE_CMDT_DVSN_CODE} eq 'BNT'  or ${item.SALE_CMDT_DVSN_CODE} eq 'JNT'">-->
#  <!-- 배송정보 영역 -->
#  <!--바로드림 전용상품이 아닐경우-->
#  <div class="prod_order_state">
#  <div class="order_state_desc">
#  <!--<span>지금 주문하면</span> -->
#  <!--<br> -->
#  <span class="fw_bold">6/18(화)</span>
#  <br/>
#  <span>도착</span>
#  </div>
#  </div>
#  <!-- // 배송정보 영역 -->
#  <!--</th:block>-->
#  <!-- 리스트형 타입 버튼영역 -->
#  <div class="prod_btn_wrap">
#  <!--결제기능, 좋아요 버튼 정책 레이아웃-->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9788956749761" data-pid="S000213299307" id="searchWishItemInfo_S000213299307" name="001_001_S000213299307_searchWishItemNm" type="hidden"/>
#  <button class="btn_wish_icon" data-cmdtcode="9788956749761" id="S000213299307_CMDTCODE_ICON" onclick='searchResultWishClickEvent(this, false, "S000213299307");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000213299307_CMDTCODE_VAL">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <!--캐스팅일때-->
#  <!--결제기능 버튼 정책 레이아웃-->
#  <div class="btn_wrap full">
#  <!--교보일때-->
#  <!--판매중/예약중 일떄-->
#  <!--or-->
#  <!--KOR,PBC,ENG,JAP AND CMDT_CDTN_CODE = 002, 019, 010, 049, 003, 016, 017 AND REAL_INVN_QNTT 0 -> 2022.10.20 해당 조건 제거 요청으로 제거 완료 -->
#  <a class="btn_sm btn_light_gray" href="javascript:;" onclick='searchResultCartClickEvent(false, "S000213299307");'><span class="text">장바구니</span></a>
#  <a class="btn_sm btn_line_primary" href="javascript:;" onclick='searchResultDirectPickUpClickEvent("S000213299307");'><span class="text">바로드림</span></a>
#  <a class="btn_sm btn_primary" href="javascript:;" onclick='searchResultDirectOrderClickEvent("S000213299307");'><span class="text">바로구매</span></a>
#  <!--품절 상품일때-->
#  <!--출시예정 상품일때-->
#  <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '004'">
#                  <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000213299307, SGK, KOR);"><span class="ico_alarm"></span><span class="text">출시알림</span></button>
#              </th:block>-->
#  <!--절판,품절,일시품절 일때-->
#  <!--<th:block th:if="${item.CMDT_CDTN_CODE} eq '003' or ${item.CMDT_CDTN_CODE} eq '002' or ${item.CMDT_CDTN_CODE} eq '010' or ${item.CMDT_CDTN_CODE} eq '011'">
#                  <th:block th:if="${item.SALE_CMDT_DVSN_CODE} ne 'GFC'">
#                      <button type="button" class="btn_sm btn_line_primary" th:onclick="clickProdAlarm(S000213299307, , KOR);"><span class="ico_alarm"></span>
#                          <th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재판매알림</span></th:block>
#                          <th:block th:unless="${item.SALE_CMDT_DVSN_CODE} eq 'PBC'"><span class="text">재입고알림</span></th:block>
#                      </button>
#                  </th:block>
#              </th:block>-->
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  <!--<th:block th:if="${item.SALE_CMDT_DVSN_CODE} eq 'MUC' or ${item.SALE_CMDT_DVSN_CODE} eq 'DVD' or ${item.SALE_CMDT_DVSN_CODE} eq 'GFT'">-->
#  <!-- 앨범 일때-->
#  <!--중고 장터일때-->
#  </div>
#  <!--//결제기능, 좋아요 버튼 정책 레이아웃-->
#  <ul class="prod_related_list">
#  <li class="btn_item">
#  <a class="btn_xxs btn_pill btn_line_gray" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007720029" onclick="searchResultItemClickEvent('eBook', &quot;S000213299307&quot;);">
#  <span class="text">eBook</span><span class="ico_arw"></span>
#  </a>
#  </li>
#
#  q
#
#
#
#
#                  </ul>
#  </div>
#  </li>,
#  <li class="prod_item">
#  <!-- 체크박스 영역 -->
#  <!-- 체크박스 영역 -->
#  <span class="form_chk no_label">
#  <!--교보일때-->
#  <input class="result_checkbox spec_checkbox" data-bid="9791158394851" data-cdtn-code="001" data-code="KOR" data-comb-code="0" data-grp-code="SGK" data-name="생성형 AI 업무 혁신" data-pid="S000212219231" data-prhb-age="0" id="chkSearch_S000212219231" name="001_001_S000212219231_chkSearchNm" type="checkbox"/>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  <!--중고 장터일때-->
#  <label for="chkSearch_S000212219231"><span class="hidden">상품선택</span></label>
#  </span>
#  <!-- // 체크박스 영역 -->
#  <!-- 상품 영역 -->
#  <div class="prod_area horizontal">
#  <div class="prod_thumb_box size_lg">
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000212219231" onclick="searchResultItemClickEvent('상품 썸네일', &quot;S000212219231&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791158394851" data-kbbfn-pid="S000212219231" data-kbbfn-size="200x0" data-kbbfn-title="생성형 AI 업무 혁신" data-kbbfn-type="KOR">
#  </img></span>
#  </a>
#  <div class="prod_viewer_control">
#  <button class="btn_prod_viewer" onclick="searchResultPreviewClickEvent('미리보기', &quot;S000212219231&quot;);" type="button"><span class="ico_preview"></span><span class="text">미리보기</span></button>
#  </div>
#  </div>
#  <div class="prod_info_box">
#  <!-- 라벨 -->
#  <!-- 라벨 페이지 -->
#  <div class="prod_badge">
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <!-- DESC : 썸네일로 보기 타입에서 노출되는 뱃지 [ rep ] class 추가 -->
#  <span class="badge_md badge_line_gray"><span class="text">이벤트</span></span>
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  </div>
#  <!-- // 라벨 -->
#  <!-- 상품명 -->
#  <div class="auto_overflow_wrap prod_name_group">
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212219231" onclick="searchResultItemClickEvent('상품 제목', &quot;S000212219231&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000212219231">생성형 AI 업무 혁신</span>
#  </a>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAllProdTitle" onclick='goTitlePopup("S000212219231");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  <!-- LayerPopup area -->
#  <!-- 타이틀 전체보기 -->
#  <div class="dialog_wrap no_title" id="popAllProdTitle">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <div class="prod_detail_title_wrap">
#  <!-- prod_title_area -->
#  <div class="prod_title_area">
#  <!-- 상품 타이틀 -->
#  <div class="prod_title_box">
#  <!-- DESC : 상품 타이틀 구분 값 케이스
#                          - 일반 구분 값 : .prod_label
#                          - 관칭관제 : .prod_alias
#                          - 상품명 : .prod_title
#                      -->
#  <span class="prod_label" id="gubun1"></span>
#  <span class="gap gubun2">·</span>
#  <span class="prod_label" id="gubun2"></span>
#  <span class="gap gubun3">·</span>
#  <span class="prod_label" id="gubun3"></span>
#  <!-- 수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  <h1>
#  <span class="prod_alias" id="kwch"></span>
#  <span class="prod_title" id="cmdtName"></span>
#  </h1>
#  <!-- //수정 220425 SEO H태그 적용. 관칭관제 + 상품명 -->
#  </div>
#  <!-- //상품 타이틀 -->
#  </div>
#  <!-- //prod_title_area -->
#  <!-- prod_desc_area -->
#  <div class="prod_desc_area">
#  <!-- DESC : 상품 타이틀 (스크립트 적용되어 있음) 자세한 내용은 가이드 참고 부탁드립니다. -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc" id="subtitle_1"></span>
#  <span class="gap subtitle_2"> | </span>
#  <span class="prod_desc" id="subtitle_2"></span>
#  <span class="gap subtitle_3"> | </span>
#  <span class="prod_desc" id="subtitle_3"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_box">
#  <!-- DESC : 상품 부제명 / 부가 정보 구분 값 케이스
#                          - 부제명 : 추가 클래스 X
#                          - 일반 부가 정보 : .normal 클래스 추가
#                      -->
#  <span class="prod_desc normal" id="splmCntt"></span>
#  <span class="gap bkbnShpName"> | </span>
#  <span class="prod_desc normal" id="bkbnShpName"></span>
#  <span class="gap setCnfgCmdtQntt"> | </span>
#  <span class="prod_desc normal" id="setCnfgCmdtQntt"></span>
#  </div>
#  <!-- //상품 부제명 -->
#  </div>
#  <!-- //prod_desc_area -->
#  </div>
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- //타이틀 전체보기 -->
#  <!-- // LayerPopup area -->
#  </div>
#  </div>
#  <!-- // 상품명 -->
#  <!-- 상품 부제명 -->
#  <div class="prod_desc_info">
#  <span class="prod_desc">배워서 바로 쓰는 DeepL, ChatGPT, GPTs, DALL-E 3, GPT-4 Analysis (위키북스 with AI 시리즈  9)</span>
#  </div>
#  <!-- // 상품 부제명 -->
#  <!-- 저자, 출판사 정보 -->
#  <div class="prod_author_info">
#  <!-- 강연/공연 인물명, 여행사인경우 type_culture class 추가 -->
#  <div class="auto_overflow_wrap prod_author_group">
#  <!--인물 페이지-->
#  <!--인물역할코드@인물코드@인물명|인물역할코드@인물코드@인물명-->
#  <div class="auto_overflow_contents">
#  <div class="auto_overflow_inner">
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author rep" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1000168411&quot;,&quot;\uBC15\uCC2C\uADDC&quot;);">박찬규</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">저자(글)</span>
#  <span class="gap"> | </span>
#  <!--인물 페이지-->
#  <!-- DESC :썸네일로 보기 타입에서 노출되는 대표 1명 저자에 [ rep ] class 추가 -->
#  <a class="author" href="javascript:void(0);" onclick="goClickSearchPage('chrc',&quot;1114352202&quot;,&quot;\uC724\uAC00\uD76C&quot;);">윤가희</a>
#  <!--인물역할코드 페이지-->
#  <!--인물역할코드-->
#  <span class="type">저자(글)</span>
#  <span class="count">외</span>
#  </div>
#  </div>
#  <div class="auto_overflow_footer">
#  <button class="btn_more_detail" data-role="btn-dialog" data-target="#popAuthorView" onclick='goAuthorPopup("001@1000168411@\uBC15\uCC2C\uADDC|001@1114352202@\uC724\uAC00\uD76C");' type="button"><span class="hidden">더보기</span><span class="ico_plus"></span></button>
#  </div>
#  <!--인물 페이지-->
#  <!-- LayerPopup area -->
#  <!-- 저자 모두보기 팝업 -->
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <div class="dialog_wrap dialog_author" data-class="dialog_sm" id="popAuthorView">
#  <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
#  <!-- dialog_header -->
#  <div class="dialog_header">
#  <h1 class="dialog_title">저자 모두보기</h1><!-- 수정 220425 SEO H태그 적용 -->
#  </div>
#  <!-- //dialog_header -->
#  <!-- dialog_contents -->
#  <div class="dialog_contents">
#  <div class="custom_scroll_wrap">
#  <!-- form_wrap -->
#  <div class="form_wrap type_md" id="authorBox">
#  </div>
#  <!-- //form_wrap -->
#  </div>
#  </div>
#  <!-- //dialog_contents -->
#  </div>
#  <!-- 수정 211207 div.dialog_author 클래스 추가 -->
#  <!-- //저자 모두보기 팝업 -->
#  <!-- // LayerPopup area -->
#  </div>
#  <div class="prod_publish">
#  <a class="text" href="javascript:void(0);" onclick="goClickSearchPage('pbcm',&quot;PB22134&quot;,&quot;\uC704\uD0A4\uBD81\uC2A4&quot;);">위키북스</a>
#  <span class="gap">·</span>
#  <span class="date">2024년 02월 15일</span>
#  </div>
#  </div>
#  <!-- // 저자, 출판사 정보 -->
#  <!--가격정보 페이지-->
#  <!-- 가격정보 페이지 -->
#  <!--판매중일떄-->
#  <!--교보일때-->
#  <!--종이책, 컬쳐(유료), GIFT일때-->
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">19,800</span>
#  <span class="unit">원 </span>
#  </span>
#  <span class="price_normal">
#  <span class="text">정가</span>
#  <s class="val">22,000원</s>
#  </span>
#  <span class="gap">|</span>
#  <span class="point">
#                              1,100p
#                              <span class="rate">(5%)</span>
#  </span>
#  </div>
#  <!--ebook/sam 일때-->
#  <!--핫트랙스일때-->
#  <!--판매중이 아닐떄-->
#  <!--중고 장터일때-->
#  <!--//가격정보 페이지-->
#  <!-- 리뷰 정보, 썸네일형 찜하기 버튼 -->
#  <div class="prod_bottom">
#  <!--좋아요 버튼(썸네일) 정책 레이아웃-->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791158394851" data-pid="S000212219231" id="searchWishItemInfo_S000212219231" name="001_001_S000212219231_searchWishItemNm" type="hidden"/>
# ...
#  <span class="prod_name">[국내도서] 챗GPT와 업무자동화</span>
#  </a>
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">16,200</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(900p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791158394288" data-pid="S000201248154" id="searchWishLogRecommendItemInfo_S000201248154" name="001_001_S000201248154_searchWishLogRecommendItemNm" type="hidden"/>
#  <button class="btn_wish_icon has_val" data-cmdtcode="9791158394288" id="S000201248154_CMDTCODE_ICON_RECOMMEND" onclick='searchResultLogRecommendWishClickEvent(this, "S000201248154");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000201248154_CMDTCODE_VAL_RECOMMEND">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item swiper-slide">
#  <div class="prod_area">
#  <div class="prod_thumb_box">
#  <!--핫트랙스일때-->
#  <!--// 핫트랙스일때-->
#  <!--핫트랙스 아닐때-->
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000213222930" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 썸네일', &quot;S000213222930&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="1400000696422" data-kbbfn-pid="S000213222930" data-kbbfn-size="200x0" data-kbbfn-title="ChatGPT를 활용한 데이터 시각화" data-kbbfn-type="POD" onerror="autoOnErrorImage(this);">
#  </img></span>
#  </a>
#  <!--// 핫트랙스 아닐때-->
#  </div>
#  <div class="prod_info_box">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213222930" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000213222930&quot;);">
#  <span class="prod_name">[POD] ChatGPT를 활용한 데이터 시각화</span>
#  </a>
#  <div class="prod_price">
#  <span class="price">
#  <span class="val">45,500</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(1,360p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item swiper-slide">
#  <div class="prod_area">
#  <div class="prod_thumb_box">
#  <!--핫트랙스일때-->
#  <!--// 핫트랙스일때-->
#  <!--핫트랙스 아닐때-->
#  <a class="prod_link" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007506544" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 썸네일', &quot;E000007506544&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="480D240538080" data-kbbfn-pid="E000007506544" data-kbbfn-size="200x0" data-kbbfn-title="디지털 강사가 알려주는 Chat GPT와 인공지능(AI) 활용법" data-kbbfn-type="EBK" onerror="autoOnErrorImage(this);">
#  </img></span>
#  </a>
#  <!--// 핫트랙스 아닐때-->
#  </div>
#  <div class="prod_info_box">
#  <a class="prod_info" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007506544" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;E000007506544&quot;);">
#  <span class="prod_name">[eBook] 디지털 강사가 알려주는 Chat GPT와 인공지능(AI) 활용법</span>
#  </a>
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">8,820</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(490p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <!--ebook/sam일때-->
#  <!--sam일때-->
#  <input data-bid="480D240538080" data-pid="E000007506544" id="searchWishLogRecommendItemInfo_E000007506544" name="005_001_E000007506544_searchWishLogRecommendItemNm" type="hidden"/>
#  <button class="btn_wish_icon has_val" data-cmdtcode="480D240538080" id="E000007506544_CMDTCODE_ICON_RECOMMEND" onclick='searchResultLogRecommendWishClickEvent(this, "E000007506544");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="E000007506544_CMDTCODE_VAL_RECOMMEND">0</span>
#  </button>
#  <!--ebook일떄-->
#  <!--핫트랙스일때-->
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item swiper-slide">
#  <div class="prod_area">
#  <div class="prod_thumb_box">
#  <!--핫트랙스일때-->
#  <!--// 핫트랙스일때-->
#  <!--핫트랙스 아닐때-->
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000212194979" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 썸네일', &quot;S000212194979&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791170462262" data-kbbfn-pid="S000212194979" data-kbbfn-size="200x0" data-kbbfn-title="비즈니스·교육·일상에서의 ChatGPT 활용 전략" data-kbbfn-type="KOR" onerror="autoOnErrorImage(this);">
#  </img></span>
#  </a>
#  <!--// 핫트랙스 아닐때-->
#  </div>
#  <div class="prod_info_box">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212194979" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000212194979&quot;);">
#  <span class="prod_name">[국내도서] 비즈니스·교육·일상에서의 ChatGPT 활용 전략</span>
#  </a>
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">18,000</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(1,000p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791170462262" data-pid="S000212194979" id="searchWishLogRecommendItemInfo_S000212194979" name="001_001_S000212194979_searchWishLogRecommendItemNm" type="hidden"/>
#  <button class="btn_wish_icon has_val" data-cmdtcode="9791170462262" id="S000212194979_CMDTCODE_ICON_RECOMMEND" onclick='searchResultLogRecommendWishClickEvent(this, "S000212194979");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000212194979_CMDTCODE_VAL_RECOMMEND">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item swiper-slide">
#  <div class="prod_area">
#  <div class="prod_thumb_box">
#  <!--핫트랙스일때-->
#  <!--// 핫트랙스일때-->
#  <!--핫트랙스 아닐때-->
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000211987834" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 썸네일', &quot;S000211987834&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791162821190" data-kbbfn-pid="S000211987834" data-kbbfn-size="200x0" data-kbbfn-title="ChatGPT로 하는 비즈니스 데이터 분석" data-kbbfn-type="KOR" onerror="autoOnErrorImage(this);">
#  </img></span>
#  </a>
#  <!--// 핫트랙스 아닐때-->
#  </div>
#  <div class="prod_info_box">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000211987834" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000211987834&quot;);">
#  <span class="prod_name">[국내도서] ChatGPT로 하는 비즈니스 데이터 분석</span>
#  </a>
#  <div class="prod_price">
#  <span class="price">
#  <span class="val">25,000</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(750p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791162821190" data-pid="S000211987834" id="searchWishLogRecommendItemInfo_S000211987834" name="001_001_S000211987834_searchWishLogRecommendItemNm" type="hidden"/>
#  <button class="btn_wish_icon has_val" data-cmdtcode="9791162821190" id="S000211987834_CMDTCODE_ICON_RECOMMEND" onclick='searchResultLogRecommendWishClickEvent(this, "S000211987834");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000211987834_CMDTCODE_VAL_RECOMMEND">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item swiper-slide">
#  <div class="prod_area">
#  <div class="prod_thumb_box">
#  <!--핫트랙스일때-->
#  <!--// 핫트랙스일때-->
#  <!--핫트랙스 아닐때-->
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000212844577" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 썸네일', &quot;S000212844577&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791197708695" data-kbbfn-pid="S000212844577" data-kbbfn-size="200x0" data-kbbfn-title="ChatGPT 소스를 얹는 파이썬 레시피" data-kbbfn-type="KOR" onerror="autoOnErrorImage(this);">
#  </img></span>
#  </a>
#  <!--// 핫트랙스 아닐때-->
#  </div>
#  <div class="prod_info_box">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212844577" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000212844577&quot;);">
#  <span class="prod_name">[국내도서] ChatGPT 소스를 얹는 파이썬 레시피</span>
#  </a>
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">28,800</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(1,600p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791197708695" data-pid="S000212844577" id="searchWishLogRecommendItemInfo_S000212844577" name="001_001_S000212844577_searchWishLogRecommendItemNm" type="hidden"/>
#  <button class="btn_wish_icon has_val" data-cmdtcode="9791197708695" id="S000212844577_CMDTCODE_ICON_RECOMMEND" onclick='searchResultLogRecommendWishClickEvent(this, "S000212844577");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000212844577_CMDTCODE_VAL_RECOMMEND">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item swiper-slide">
#  <div class="prod_area">
#  <div class="prod_thumb_box">
#  <!--핫트랙스일때-->
#  <!--// 핫트랙스일때-->
#  <!--핫트랙스 아닐때-->
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000210139087" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 썸네일', &quot;S000210139087&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791155643211" data-kbbfn-pid="S000210139087" data-kbbfn-size="200x0" data-kbbfn-title="5분 뚝딱 챗GPT" data-kbbfn-type="KOR" onerror="autoOnErrorImage(this);">
#  </img></span>
#  </a>
#  <!--// 핫트랙스 아닐때-->
#  </div>
#  <div class="prod_info_box">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000210139087" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000210139087&quot;);">
#  <span class="prod_name">[국내도서] 5분 뚝딱 챗GPT</span>
#  </a>
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">13,320</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(740p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791155643211" data-pid="S000210139087" id="searchWishLogRecommendItemInfo_S000210139087" name="001_001_S000210139087_searchWishLogRecommendItemNm" type="hidden"/>
#  <button class="btn_wish_icon has_val" data-cmdtcode="9791155643211" id="S000210139087_CMDTCODE_ICON_RECOMMEND" onclick='searchResultLogRecommendWishClickEvent(this, "S000210139087");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000210139087_CMDTCODE_VAL_RECOMMEND">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item swiper-slide">
#  <div class="prod_area">
#  <div class="prod_thumb_box">
#  <!--핫트랙스일때-->
#  <!--// 핫트랙스일때-->
#  <!--핫트랙스 아닐때-->
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000201419281" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 썸네일', &quot;S000201419281&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9791187580690" data-kbbfn-pid="S000201419281" data-kbbfn-size="200x0" data-kbbfn-title="ChatGPT 활용 핵심 가이드북" data-kbbfn-type="KOR" onerror="autoOnErrorImage(this);">
#  </img></span>
#  </a>
#  <!--// 핫트랙스 아닐때-->
#  </div>
#  <div class="prod_info_box">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201419281" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000201419281&quot;);">
#  <span class="prod_name">[국내도서] ChatGPT 활용 핵심 가이드북</span>
#  </a>
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">15,300</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(850p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9791187580690" data-pid="S000201419281" id="searchWishLogRecommendItemInfo_S000201419281" name="001_001_S000201419281_searchWishLogRecommendItemNm" type="hidden"/>
#  <button class="btn_wish_icon has_val" data-cmdtcode="9791187580690" id="S000201419281_CMDTCODE_ICON_RECOMMEND" onclick='searchResultLogRecommendWishClickEvent(this, "S000201419281");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000201419281_CMDTCODE_VAL_RECOMMEND">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item swiper-slide">
#  <div class="prod_area">
#  <div class="prod_thumb_box">
#  <!--핫트랙스일때-->
#  <!--// 핫트랙스일때-->
#  <!--핫트랙스 아닐때-->
#  <a class="prod_link" href="https://product.kyobobook.co.kr/detail/S000201418921" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 썸네일', &quot;S000201418921&quot;);">
#  <span class="img_box">
#  <img class="prod_img_load" data-kbbfn="s3-image" data-kbbfn-adult="0" data-kbbfn-attr="src" data-kbbfn-bid="9788973435548" data-kbbfn-pid="S000201418921" data-kbbfn-size="200x0" data-kbbfn-title="챗GPT4 제대로 알고 써먹자" data-kbbfn-type="KOR" onerror="autoOnErrorImage(this);">
#  </img></span>
#  </a>
#  <!--// 핫트랙스 아닐때-->
#  </div>
#  <div class="prod_info_box">
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201418921" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000201418921&quot;);">
#  <span class="prod_name">[국내도서] 챗GPT4 제대로 알고 써먹자</span>
#  </a>
#  <div class="prod_price">
#  <span class="percent">10%</span>
#  <span class="price">
#  <span class="val">15,480</span>
#  <span class="unit">원</span>
#  </span>
#  <span class="point">(860p)</span>
#  </div>
#  <div class="prod_bottom">
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!-- 좋아요 버튼 정책 레이아웃-->
#  <!-- DESC : 찜하기 버튼 활성화 시 button.btn_wish 영역 [active] class 추가 -->
#  <!--교보일때-->
#  <input data-bid="9788973435548" data-pid="S000201418921" id="searchWishLogRecommendItemInfo_S000201418921" name="001_001_S000201418921_searchWishLogRecommendItemNm" type="hidden"/>
#  <button class="btn_wish_icon has_val" data-cmdtcode="9788973435548" id="S000201418921_CMDTCODE_ICON_RECOMMEND" onclick='searchResultLogRecommendWishClickEvent(this, "S000201418921");' type="button"><span class="ico_wish"></span><span class="hidden">관심 등록</span>
#  <span class="val" id="S000201418921_CMDTCODE_VAL_RECOMMEND">0</span>
#  </button>
#  <!--ebook/sam일때-->
#  <!--핫트랙스일때-->
#  </div>
#  </div>
#  </div>
#  </li>]

# %%
prod_info = soup.find_all("a", attrs={"class": "prod_info"})
prod_info
# Out:
# [<a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213093628" onclick="searchResultItemClickEvent('상품 제목', &quot;S000213093628&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000213093628">챗GPT 프롬프트 120% 질문 기술</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212147276" onclick="searchResultItemClickEvent('상품 제목', &quot;S000212147276&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000212147276">쉽고 빠르게 익히는 실전 LLM</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213299307" onclick="searchResultItemClickEvent('상품 제목', &quot;S000213299307&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000213299307">예제가 가득한 챗GPT 프롬프트 길라잡이</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212219231" onclick="searchResultItemClickEvent('상품 제목', &quot;S000212219231&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000212219231">생성형 AI 업무 혁신</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212969433" onclick="searchResultItemClickEvent('상품 제목', &quot;S000212969433&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000212969433">OpenAI API와 파이썬으로 나만의 챗GPT 만들기</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212732017" onclick="searchResultItemClickEvent('상품 제목', &quot;S000212732017&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000212732017">LangChain으로 구현하는 LLM</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000208577519" onclick="searchResultItemClickEvent('상품 제목', &quot;S000208577519&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000208577519">챗GPT와 데이터 분석 with 코드 인터프리터</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201458960" onclick="searchResultItemClickEvent('상품 제목', &quot;S000201458960&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000201458960">챗GPT와 기획 분석 보고</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000209182535" onclick="searchResultItemClickEvent('상품 제목', &quot;S000209182535&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000209182535">GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201248154" onclick="searchResultItemClickEvent('상품 제목', &quot;S000201248154&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000201248154">챗GPT와 업무자동화</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201295361" onclick="searchResultItemClickEvent('상품 제목', &quot;S000201295361&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000201295361">챗GPT 교육혁명</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201408487" onclick="searchResultItemClickEvent('상품 제목', &quot;S000201408487&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000201408487">챗GPT + 엑셀 업무자동화 정석</span>
#  </a>,
#  <a class="prod_info" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007719746" onclick="searchResultItemClickEvent('상품 제목', &quot;E000007719746&quot;);">
#  <span class="prod_category">[eBook]</span>
#  <span id="cmdtName_E000007719746">챗GPT 프롬프트 120% 질문 기술</span>
#  </a>,
#  <a class="prod_info" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000006748906" onclick="searchResultItemClickEvent('상품 제목', &quot;E000006748906&quot;);">
#  <span class="prod_category">[eBook]</span>
#  <span id="cmdtName_E000006748906">생성형 AI 업무 혁신</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000208506795" onclick="searchResultItemClickEvent('상품 제목', &quot;S000208506795&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000208506795">진짜 챗GPT API 활용법</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213350172" onclick="searchResultItemClickEvent('상품 제목', &quot;S000213350172&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000213350172">AI 활용, 단숨에 뚝딱! 책쓰기</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000209071127" onclick="searchResultItemClickEvent('상품 제목', &quot;S000209071127&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000209071127">오늘부터 프로듀서! 아이패드로 나만의 음악 만들기 with 개러지밴드</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000202404483" onclick="searchResultItemClickEvent('상품 제목', &quot;S000202404483&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000202404483">엑셀 매크로&amp;VBA 바이블</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201060847" onclick="searchResultItemClickEvent('상품 제목', &quot;S000201060847&quot;);">
#  <span class="prod_category">[국내도서]</span>
#  <span id="cmdtName_S000201060847">챗GPT와 글쓰기</span>
#  </a>,
#  <a class="prod_info" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000006084010" onclick="searchResultItemClickEvent('상품 제목', &quot;E000006084010&quot;);">
#  <span class="prod_category">[eBook]</span>
#  <span id="cmdtName_E000006084010">GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213093628" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000213093628&quot;);">
#  <span class="prod_name">[국내도서] 챗GPT 프롬프트 120% 질문 기술</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213299307" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000213299307&quot;);">
#  <span class="prod_name">[국내도서] 예제가 가득한 챗GPT 프롬프트 길라잡이</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212219231" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000212219231&quot;);">
#  <span class="prod_name">[국내도서] 생성형 AI 업무 혁신</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212969433" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000212969433&quot;);">
#  <span class="prod_name">[국내도서] OpenAI API와 파이썬으로 나만의 챗GPT 만들기</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000203182748" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000203182748&quot;);">
#  <span class="prod_name">[국내도서] ChatGPT 업무 · 비즈니스 활용 전략</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000209182535" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000209182535&quot;);">
#  <span class="prod_name">[국내도서] GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201248154" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000201248154&quot;);">
#  <span class="prod_name">[국내도서] 챗GPT와 업무자동화</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000213222930" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000213222930&quot;);">
#  <span class="prod_name">[POD] ChatGPT를 활용한 데이터 시각화</span>
#  </a>,
#  <a class="prod_info" href="https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007506544" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;E000007506544&quot;);">
#  <span class="prod_name">[eBook] 디지털 강사가 알려주는 Chat GPT와 인공지능(AI) 활용법</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212194979" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000212194979&quot;);">
#  <span class="prod_name">[국내도서] 비즈니스·교육·일상에서의 ChatGPT 활용 전략</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000211987834" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000211987834&quot;);">
#  <span class="prod_name">[국내도서] ChatGPT로 하는 비즈니스 데이터 분석</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000212844577" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000212844577&quot;);">
#  <span class="prod_name">[국내도서] ChatGPT 소스를 얹는 파이썬 레시피</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000210139087" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000210139087&quot;);">
#  <span class="prod_name">[국내도서] 5분 뚝딱 챗GPT</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201419281" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000201419281&quot;);">
#  <span class="prod_name">[국내도서] ChatGPT 활용 핵심 가이드북</span>
#  </a>,
#  <a class="prod_info" href="https://product.kyobobook.co.kr/detail/S000201418921" onclick="searchResultLogRecommendItemClickEvent('함께 많이 본 상품 제목', &quot;S000201418921&quot;);">
#  <span class="prod_name">[국내도서] 챗GPT4 제대로 알고 써먹자</span>
#  </a>]

# %%
len(prod_info)
# Out:
# 35

# %%
for prod in prod_info:
    print(prod.text.strip())
    print(prod.get("href"))
# Out:
# [국내도서]
# 챗GPT 프롬프트 120% 질문 기술
# https://product.kyobobook.co.kr/detail/S000213093628
# [국내도서]
# 쉽고 빠르게 익히는 실전 LLM
# https://product.kyobobook.co.kr/detail/S000212147276
# [국내도서]
# 예제가 가득한 챗GPT 프롬프트 길라잡이
# https://product.kyobobook.co.kr/detail/S000213299307
# [국내도서]
# 생성형 AI 업무 혁신
# https://product.kyobobook.co.kr/detail/S000212219231
# [국내도서]
# OpenAI API와 파이썬으로 나만의 챗GPT 만들기
# https://product.kyobobook.co.kr/detail/S000212969433
# [국내도서]
# LangChain으로 구현하는 LLM
# https://product.kyobobook.co.kr/detail/S000212732017
# [국내도서]
# 챗GPT와 데이터 분석 with 코드 인터프리터
# https://product.kyobobook.co.kr/detail/S000208577519
# [국내도서]
# 챗GPT와 기획 분석 보고
# https://product.kyobobook.co.kr/detail/S000201458960
# [국내도서]
# GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍
# https://product.kyobobook.co.kr/detail/S000209182535
# [국내도서]
# 챗GPT와 업무자동화
# https://product.kyobobook.co.kr/detail/S000201248154
# [국내도서]
# 챗GPT 교육혁명
# https://product.kyobobook.co.kr/detail/S000201295361
# [국내도서]
# 챗GPT + 엑셀 업무자동화 정석
# https://product.kyobobook.co.kr/detail/S000201408487
# [eBook]
# 챗GPT 프롬프트 120% 질문 기술
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007719746
# [eBook]
# 생성형 AI 업무 혁신
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000006748906
# [국내도서]
# 진짜 챗GPT API 활용법
# https://product.kyobobook.co.kr/detail/S000208506795
# [국내도서]
# AI 활용, 단숨에 뚝딱! 책쓰기
# https://product.kyobobook.co.kr/detail/S000213350172
# [국내도서]
# 오늘부터 프로듀서! 아이패드로 나만의 음악 만들기 with 개러지밴드
# https://product.kyobobook.co.kr/detail/S000209071127
# [국내도서]
# 엑셀 매크로&VBA 바이블
# https://product.kyobobook.co.kr/detail/S000202404483
# [국내도서]
# 챗GPT와 글쓰기
# https://product.kyobobook.co.kr/detail/S000201060847
# [eBook]
# GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000006084010
# [국내도서] 챗GPT 프롬프트 120% 질문 기술
# https://product.kyobobook.co.kr/detail/S000213093628
# [국내도서] 예제가 가득한 챗GPT 프롬프트 길라잡이
# https://product.kyobobook.co.kr/detail/S000213299307
# [국내도서] 생성형 AI 업무 혁신
# https://product.kyobobook.co.kr/detail/S000212219231
# [국내도서] OpenAI API와 파이썬으로 나만의 챗GPT 만들기
# https://product.kyobobook.co.kr/detail/S000212969433
# [국내도서] ChatGPT 업무 · 비즈니스 활용 전략
# https://product.kyobobook.co.kr/detail/S000203182748
# [국내도서] GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍
# https://product.kyobobook.co.kr/detail/S000209182535
# [국내도서] 챗GPT와 업무자동화
# https://product.kyobobook.co.kr/detail/S000201248154
# [POD] ChatGPT를 활용한 데이터 시각화
# https://product.kyobobook.co.kr/detail/S000213222930
# [eBook] 디지털 강사가 알려주는 Chat GPT와 인공지능(AI) 활용법
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007506544
# [국내도서] 비즈니스·교육·일상에서의 ChatGPT 활용 전략
# https://product.kyobobook.co.kr/detail/S000212194979
# [국내도서] ChatGPT로 하는 비즈니스 데이터 분석
# https://product.kyobobook.co.kr/detail/S000211987834
# [국내도서] ChatGPT 소스를 얹는 파이썬 레시피
# https://product.kyobobook.co.kr/detail/S000212844577
# [국내도서] 5분 뚝딱 챗GPT
# https://product.kyobobook.co.kr/detail/S000210139087
# [국내도서] ChatGPT 활용 핵심 가이드북
# https://product.kyobobook.co.kr/detail/S000201419281
# [국내도서] 챗GPT4 제대로 알고 써먹자
# https://product.kyobobook.co.kr/detail/S000201418921

# %%
def get_product_list(keyword: str) -> list:
    """Search product list by keyword and then return product list"""
    url = f"https://search.kyobobook.co.kr/search?keyword={keyword}&gbCode=TOT&target=total"
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        prod_info = soup.find_all("a", attrs={"class": "prod_info"})
        prod_list = [
            {"title": prod.text.strip(), "link": prod.get("href")} for prod in prod_info
        ]
        return prod_list
    else:
        return []

# %%
prod_list = get_product_list("텐서플로")
prod_list
# Out:
# [{'title': '[국내도서]\n핸즈온 머신러닝',
#   'link': 'https://product.kyobobook.co.kr/detail/S000208981368'},
#  {'title': '[국내도서]\n이미지 처리 바이블',
#   'link': 'https://product.kyobobook.co.kr/detail/S000213080089'},
#  {'title': '[eBook]\n[epub3.0] 이미지 처리 바이블',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007594703'},
#  {'title': '[국내도서]\n선형대수와 통계학으로 배우는 머신러닝 with 파이썬',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001842169'},
#  {'title': '[국내도서]\n머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001834604'},
#  {'title': '[eBook]\n선형대수와 통계학으로 배우는 머신러닝 with 파이썬',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002955315'},
#  {'title': '[국내도서]\n딥러닝 텐서플로 교과서',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001834615'},
#  {'title': '[국내도서]\nGAN 인 액션',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001810307'},
#  {'title': '[국내도서]\n텐서플로와 케라스로 구현하는 딥러닝',
#   'link': 'https://product.kyobobook.co.kr/detail/S000208392635'},
#  {'title': '[국내도서]\n실전! 컴퓨터비전을 위한 머신러닝',
#   'link': 'https://product.kyobobook.co.kr/detail/S000202999618'},
#  {'title': '[국내도서]\n텐서플로로 배우는 수치최적화와 딥러닝',
#   'link': 'https://product.kyobobook.co.kr/detail/S000200033295'},
#  {'title': '[국내도서]\n살아 움직이는 머신러닝 파이프라인 설계',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001810440'},
#  {'title': '[국내도서]\n웹 브라우저 속 머신러닝 TensorFlow.js',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001810423'},
#  {'title': '[국내도서]\n실전! 텐서플로 2를 활용한 딥러닝 컴퓨터 비전',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001766435'},
#  {'title': '[국내도서]\n파이썬 딥러닝 텐서플로',
#   'link': 'https://product.kyobobook.co.kr/detail/S000000833270'},
#  {'title': '[eBook]\n텐서플로 2와 머신러닝으로 시작하는 자연어 처리',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000005077547'},
#  {'title': '[eBook]\n퀀트 투자를 위한 머신러닝·딥러닝 알고리듬 트레이딩 2/e',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000005062167'},
#  {'title': '[eBook]\n웹 브라우저 속 머신러닝 TensorFlow.js',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002942564'},
#  {'title': '[eBook]\n딥러닝 텐서플로 교과서',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002950736'},
#  {'title': '[eBook]\n실전! GAN 프로젝트',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000005295817'},
#  {'title': '[국내도서] 텐서플로와 케라스로 구현하는 딥러닝',
#   'link': 'https://product.kyobobook.co.kr/detail/S000208392635'},
#  {'title': '[국내도서] 핸즈온 머신러닝',
#   'link': 'https://product.kyobobook.co.kr/detail/S000208981368'},
#  {'title': '[국내도서] 딥러닝 텐서플로 교과서',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001834615'},
#  {'title': '[국내도서] 실전! 텐서플로 2를 활용한 딥러닝 컴퓨터 비전',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001766435'},
#  {'title': '[국내도서] 이미지 처리 바이블',
#   'link': 'https://product.kyobobook.co.kr/detail/S000213080089'},
#  {'title': '[국내도서] 머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001834604'},
#  {'title': '[국내도서] 딥러닝 with 텐서플로와 케라스',
#   'link': 'https://product.kyobobook.co.kr/detail/S000211692994'},
#  {'title': '[국내도서] 텐서플로로 배우는 수치최적화와 딥러닝',
#   'link': 'https://product.kyobobook.co.kr/detail/S000200033295'},
#  {'title': '[국내도서] 생활코딩 머신러닝 실습편 with 파이썬 텐서플로',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001766496'},
#  {'title': '[eBook] 텐서플로 케라스를 이용한 딥러닝',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000005127772'},
#  {'title': '[국내도서] 러닝 텐서플로',
#   'link': 'https://product.kyobobook.co.kr/detail/S000001810042'},
#  {'title': '[국내도서] 텐서플로 케라스를 이용한 딥러닝',
#   'link': 'https://product.kyobobook.co.kr/detail/S000200883646'},
#  {'title': '[국내도서] 파이썬 딥러닝 텐서플로',
#   'link': 'https://product.kyobobook.co.kr/detail/S000000833270'},
#  {'title': '[eBook] 텐서플로 2와 머신러닝으로 시작하는 자연어 처리',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000005077547'},
#  {'title': '[eBook] 생활코딩 머신러닝 실습편 with 파이썬 텐서플로',
#   'link': 'https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002928549'}]

# %%
# !pip3 install selenium
# Out:
# Collecting selenium
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/e0/7a/08f0ea19a0c835e88aad011083d9dda69a9dfa4585c3453b3bd842eb7bed/selenium-4.21.0-py3-none-any.whl.metadata
#   Downloading selenium-4.21.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/apple/anaconda3/lib/python3.11/site-packages (from selenium) (1.26.16)
# Collecting trio~=0.17 (from selenium)
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/76/51/12d78ec8abcbda51d8f115d98ebd3ee3da9d9d9af00ac69d3097c5b8d51a/trio-0.25.1-py3-none-any.whl.metadata
#   Downloading trio-0.25.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/apple/anaconda3/lib/python3.11/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.9.0 in /Users/apple/anaconda3/lib/python3.11/site-packages (from selenium) (4.9.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Obtaining dependency information for attrs>=23.2.0 from https://files.pythonhosted.org/packages/e0/44/827b2a91a5816512fcaf3cc4ebc465ccd5d598c45cefa6703fcf4a79018f/attrs-23.2.0-py3-none-any.whl.metadata
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: sortedcontainers in /Users/apple/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/apple/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Obtaining dependency information for outcome from https://files.pythonhosted.org/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl.metadata
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Obtaining dependency information for sniffio>=1.3.0 from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Obtaining dependency information for wsproto>=0.14 from https://files.pythonhosted.org/packages/78/58/e860788190eba3bcce367f74d29c4675466ce8dddfba85f7827588416f01/wsproto-1.2.0-py3-none-any.whl.metadata
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/apple/anaconda3/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/apple/anaconda3/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.21.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 9.2 MB/s eta 0:00:0000:0100:01m
# Downloading trio-0.25.1-py3-none-any.whl (467 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.7/467.7 kB 6.0 MB/s eta 0:00:0000:01:00:01
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: wsproto, sniffio, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.1.5 requires langsmith<0.1,>=0.0.83, but you have langsmith 0.1.27 which is incompatible.
# Successfully installed attrs-23.2.0 outcome-1.3.0.post0 selenium-4.21.0 sniffio-1.3.1 trio-0.25.1 trio-websocket-0.11.1 wsproto-1.2.0

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import ChromeOptions

options = ChromeOptions()
# options.add_argument("--headless=new")
driver = webdriver.Chrome(options=options)

keyword = "텐서플로"
url = f"https://search.kyobobook.co.kr/search?keyword={keyword}&gbCode=TOT&target=total"
driver.get(url)

# %%
prod_item = driver.find_elements(By.CLASS_NAME, "prod_info")

# %%
for prod in prod_item[:10]:
    print(prod.text.strip())
    print(prod.get_attribute("href"))
# Out:
# [국내도서] 핸즈온 머신러닝
# https://product.kyobobook.co.kr/detail/S000208981368
# [국내도서] 이미지 처리 바이블
# https://product.kyobobook.co.kr/detail/S000213080089
# [eBook] [epub3.0] 이미지 처리 바이블
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000007594703
# [국내도서] 선형대수와 통계학으로 배우는 머신러닝 with 파이썬
# https://product.kyobobook.co.kr/detail/S000001842169
# [국내도서] 머신 러닝 교과서 with 파이썬, 사이킷런, 텐서플로
# https://product.kyobobook.co.kr/detail/S000001834604
# [eBook] 선형대수와 통계학으로 배우는 머신러닝 with 파이썬
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002955315
# [국내도서] 딥러닝 텐서플로 교과서
# https://product.kyobobook.co.kr/detail/S000001834615
# [국내도서] GAN 인 액션
# https://product.kyobobook.co.kr/detail/S000001810307
# [국내도서] 텐서플로와 케라스로 구현하는 딥러닝
# https://product.kyobobook.co.kr/detail/S000208392635
# [국내도서] 실전! 컴퓨터비전을 위한 머신러닝
# https://product.kyobobook.co.kr/detail/S000202999618

# %%
driver.get("https://product.kyobobook.co.kr/detail/S000000833270")
table_of_contents = driver.find_element(By.CLASS_NAME, "book_contents_item").text
print(table_of_contents)
# Out:
# PART 01 개발 환경 구축
# 01 구글 코랩
# 02 구글 코랩 설치
# 03 구글 코랩 실행
# 04 예제 코드 복사하기
#
# PART 02 텐서플로(TensorFlow)
# 01 텐서플로
# 02 텐서플로2 주요 특징
# 03 텐서플로 자료구조
# 04 인덱싱(indexing)
# 05 형태 변환(tf.reshape)
# 06 변수(tf.Variable)
# 07 자동 미분(Automatic Differentiation)
#
# PART 03 케라스(Keras)
# 01 딥러닝 준비
# 02 단순 신경망 훈련
# 03 심층 신경망으로 이미지 분류
# 04 모델 세부 설정
# 05 콜백(Callback)
# 06 모델 저장 및 불러오기
# 07 복잡한 모델 생성
# 08 사용자 정의
# 09 텐서플로 데이터셋
# 10 tf.data.Dataset 클래스
#
# PART 04 합성곱 신경망(CNN)
# 01 합성곱 신경망
# 02 간단한 모델 생성
# 03 복잡한 모델 생성
# 04 위성 이미지 분류
# 05 개/고양이 분류
# 06 객체 탐지(Object Detection)
# 07 이미지 분할(Segmentation)
# 08 Knowledge Distillation
# 09 GAN
# 10 Style Transfer
# 11 Grad CAM
#
# PART 05 순환신경망
# 01 순환신경망
# 02 알고리즘
# 03 순환신경망 활용
# 04 자연어 처리(NLP)
# 05 트랜스포머
# 06 ViT
#
# PART 06 강화 학습(Reinforcement Learning)
# 01 강화 학습
# 02 환경 구성
# 03 Grid World에서 강화 학습 - Frozen Lake
# 04 연속 환경 - Cartpole
# 05 정리

# %%
def get_prod_table_of_content(url: str) -> str:
    """Get product content by url"""
    options = ChromeOptions()
    options.add_argument("--headless=new")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    contents = driver.find_element(By.CLASS_NAME, "book_contents_item").text
    driver.quit()
    return contents

# %%
table_of_contents = get_prod_table_of_content(
    "https://product.kyobobook.co.kr/detail/S000001809989"
)
print(table_of_contents)
# Out:
# 1장. 딥러닝과 텐서플로의 만남
# __1.1 인공지능, 머신러닝 그리고 딥러닝
# __1.2 왜 텐서플로인가?
#
# 2장. 텐서플로 설치와 주피터 노트북
# __2.1 파이썬 및 필수 라이브러리 설치하기
# __2.2 텐서플로 예제 내려받고 실행해보기
# __2.3 주피터 노트북
#
#
# __3.1 텐서와 그래프 실행
# __3.2 플레이스홀더와 변수
# __3.3 선형 회귀 모델 구현하기
#
#
# __4.1 인공신경망의 작동 원리
# __4.2 간단한 분류 모델 구현하기
# __4.3 심층 신경망 구현하기
#
#
# __5.1 학습 모델 저장하고 재사용하기
# __5.2 텐서보드 사용하기
# __5.3 더 보기
#
#
# __6.1 MNIST 학습하기
# __6.2 드롭아웃
# __6.3 matplotlib
#
#
# __7.1 CNN 개념
# __7.2 모델 구현하기
# __7.3 고수준 API
# __7.4 더 보기
#
#
# __8.1 오토인코더 개념
# __8.2 오토인코더 구현하기
#
#
# __9.1 GAN 기본 모델 구현하기
# __9.2 원하는 숫자 생성하기
# __9.3 더 보기
#
#
# __10.1 MNIST를 RNN으로
# __10.2 단어 자동 완성
# __10.3 Sequence to Sequence
# __10.4 더 보기
#
#
# __11.1 자료 준비
# __11.2 학습시키기
# __11.3 예측 스크립트
# __11.4 더 보기
#
#
# __12.1 DQN 개념
# __12.2 게임 소개
# __12.3 에이전트 구현하기
# __12.4 신경망 모델 구현하기
# __12.5 학습시키기
# __12.6 더 보기

# %% [markdown]
# OPEN API KEY Setting

# %%
# 토큰 정보로드를 위한 라이브러리
# 설치: pip install python-dotenv
from dotenv import load_dotenv

# 토큰 정보로드
load_dotenv()
# Out:
# True

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import ChromeOptions
from langchain.agents import tool


@tool
def get_product_list(keyword: str) -> list:
    """
    Search product list by keyword and then return product list
    keyword: search keyword
    return: product list
    """

    url = f"https://search.kyobobook.co.kr/search?keyword={keyword}&gbCode=TOT&target=total"
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        prod_info = soup.find_all("a", attrs={"class": "prod_info"})
        prod_list = [
            {"title": prod.text.strip(), "link": prod.get("href")} for prod in prod_info
        ]
        return prod_list[:5]
    else:
        return []


@tool
def get_prod_table_of_content(url: str) -> str:
    """
    Get the product's table of content by url. The url should be valid url.
    url: product url
    return: table of content
    """
    options = ChromeOptions()
    options.add_argument("--headless=new")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    contents = driver.find_element(By.CLASS_NAME, "book_contents_item").text
    driver.quit()
    return contents

# %%
# langchain agent tools
tools = [get_product_list, get_prod_table_of_content]

# %%
from langchain_community.tools.convert_to_openai import format_tool_to_openai_function
from langchain_openai import ChatOpenAI

# llm 모델 정의
llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo")

# llm 모델에 tools 바인딩
llm_with_tools = llm.bind(
    functions=[format_tool_to_openai_function(t) for t in tools])
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[24], line 5
#       2 from langchain_openai import ChatOpenAI
#       4 # llm 모델 정의
# ----> 5 llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo")
#       7 # llm 모델에 tools 바인딩
#       8 llm_with_tools = llm.bind(
#       9     functions=[format_tool_to_openai_function(t) for t in tools])
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/load/serializable.py:120, in Serializable.__init__(self, **kwargs)
#     119 def __init__(self, **kwargs: Any) -> None:
# --> 120     super().__init__(**kwargs)
#     121     self._lc_kwargs = kwargs
#
# File ~/anaconda3/lib/python3.11/site-packages/pydantic/main.py:341, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for ChatOpenAI
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass `openai_api_key` as a named parameter. (type=value_error)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder


# Prompt 정의
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are very powerful assistant, but don't know current events",
        ),
        ("user", "{input}"),
        MessagesPlaceholder(variable_name="agent_scratchpad"),
    ]
)

# %%
from langchain.agents.format_scratchpad import format_to_openai_function_messages
from langchain.agents.output_parsers import OpenAIFunctionsAgentOutputParser

# agent 정의
agent = (
    {
        "input": lambda x: x["input"],
        "agent_scratchpad": lambda x: format_to_openai_function_messages(
            x["intermediate_steps"]
        ),
    }
    | prompt
    | llm_with_tools
    | OpenAIFunctionsAgentOutputParser()
)

# %%
from langchain.agents import AgentExecutor

# agent_executor 정의
agent_executor = AgentExecutor(
    agent=agent, tools=tools, handle_parsing_errors=True, verbose=True
)

# %%
def run(agent_executor: AgentExecutor, keyword: str) -> dict:
    result = agent_executor.invoke(
        {
            "input": f"""
        1. `{keyword}` 키워드로 상품 리스트를 가져와줘.
        2. 1번 과정에서 가져온 상품 리스트 각각의 table of content 를 가져와줘.
        3. 마지막으로 모든 상품 리스트의 table of content 를 종합하여 내가 앞으로 집필할 베스트셀러 책의 목차를 작성해 줘.
        """
        }
    )
    return result["output"]

# %%
final_answer = run(agent_executor, "Pandas")

# %%
print(final_answer)
